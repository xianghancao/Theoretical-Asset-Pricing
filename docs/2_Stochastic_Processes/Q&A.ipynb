# %% [markdown]
# ## Q&A

# %% [markdown]
# ## 1. Discrete-Time
# - ![Screenshot 2025-10-13 at 17.34.23.png](attachment:16789c35-2e77-4558-922c-f7d1f2a261df.png)

# %% [markdown]
# 基于第二章“不确定性、信息与随机过程”的结构和内容，可以提出以下几类问题来测试或探讨关键概念：
#
# ---
#
# ## 概念基础与信息流问题 (Uncertainty and Information)
#
# 这类问题关注如何建模不确定性以及信息如何随时间演变。
#
# 1.  [cite_start]**概率空间的作用：** 在金融资产定价理论（FAPT）中，概率空间 $(\Omega, \mathcal{F}, \mathbb{P})$ 的三个组成部分各代表什么？特别是，$\Omega$ (状态空间) 应该包含哪些元素？[cite: 21, 22, 23]
# 2.  [cite_start]**信息与过滤 (Filtration)：** 如何形式化地表示不确定性随时间逐步消除的过程？[cite: 32, 33] [cite_start]随着信息流 $(\mathcal{F}_t)_{t\in\mathcal{T}}$ 的发展，关于随机变量 $X$ 的条件矩会发生什么变化？请说明 $\mathbb{E}_0[X]$ 和 $\mathbb{E}_T[X]$ 的关系。[cite: 39, 41]
# 3.  [cite_start]**迭代期望定律：** 请陈述迭代期望定律（Law of Iterated Expectations，定理 2.1）并解释其在金融模型中的直观意义。[cite: 39, 43]
#
# ---
#
# ## 离散时间与随机过程定义问题 (Discrete-Time and Definitions)
#
# 这类问题关注随机过程的基本定义和离散时间模型。
#
# 1.  [cite_start]**随机变量与随机过程的区别：** 随机变量 $X$ 和随机过程 $X = (X_t)_{t\in\mathcal{T}}$ 在建模金融现象时有什么根本区别？[cite: 105, 108, 109, 110]
# 2.  [cite_start]**鞅 (Martingale)：** 什么是鞅？其核心性质是什么？随机游走（Random walk）是否是鞅？[cite: 115, 116, 117, 137]
# 3.  [cite_start]**马尔可夫性 (Markov Property)：** 请定义马尔可夫过程。这个性质对金融建模有什么重要意义？[cite: 120, 121]
# 4.  [cite_start]**离散时间过程：** 请写出 AR(1) 过程的动态方程，并解释其**均值回归**特性（Mean reversion）的含义。[cite: 139, 140]
#
# ---
#
# ## 连续时间与伊藤微积分问题 (Continuous-Time and Itô Calculus)
#
# 这类问题关注连续时间模型、布朗运动和伊藤引理。
#
# 1.  [cite_start]**布朗运动的性质：** 标准布朗运动（Standard Brownian motion）的四个定义性质是什么？它在连续时间模型中扮演了什么角色？[cite: 142]
# 2.  [cite_start]**广义布朗运动：** 请写出广义布朗运动（Generalized Brownian motion）的微分形式 $dX_t$，并指出其中的 $\mu$（漂移/趋势）和 $\omega$（波动率/方差）分别代表什么。[cite: 148]
# 3.  [cite_start]**伊藤过程与扩散：** 请区分扩散（Diffusion）和伊藤过程（Itô process）。哪一个过程必定是马尔可夫的？[cite: 149, 151, 152]
# 4.  [cite_start]**随机积分的性质：** 对于一个“nice process” $\omega_u$，请陈述其随机积分 $\int_{t}^{t'}\omega_u dz_u$ 的条件期望 $E_t[\dots]$ 和条件方差 $Var_t[\dots]$ 的公式（定理 2.2）。[cite: 154]
# 5.  [cite_start]**伊藤引理 (Itô's Lemma)：** 伊藤引理（定理 2.5）与普通微积分中的链式法则（Chain Rule）有什么关键区别？请说明 $(dX_t)^2$ 在伊藤引理中的作用和取值。[cite: 157, 158]
# 6.  [cite_start]**几何布朗运动：** 请写出几何布朗运动（Geometric Brownian motion）的动态方程。为什么这个模型常被用于股票价格建模？[cite: 159, 160, 165]
#
# ---
#
# ## 多元随机过程问题 (Handling Several Processes Simultaneously)
#
# 这类问题关注多个过程之间的相关性建模。
#
# 1.  [cite_start]**单冲击与相关性：** 如果两个随机过程 $X$ 和 $Y$ 仅由**同一个**一维布朗运动 $z$ 驱动，它们的瞬时变化 $dX_t$ 和 $dY_t$ 之间的相关性 $Corrt[dX_t, dY_t]$ 是多少？请解释这个结果的含义。[cite: 167, 168, 169]
# 2.  [cite_start]**多冲击建模：** 至少需要多少个**独立的**布朗运动才能使得两个过程 $X$ 和 $Y$ 的瞬时相关性 $Corrt[dX_t, dY_t]$ 可以在 $[-1, +1]$ 之间取任意值？[cite: 171, 173]
# 3.  [cite_start]**多元伊藤引理：** 在对两个随机过程 $X_t$ 和 $Y_t$ 的函数 $W_t = g(X_t, Y_t, t)$ 应用伊藤引理（定理 2.6）时，相比单变量情况，公式中增加了哪些关键项？[cite: 178]
